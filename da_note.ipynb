# %% [raw]
# import warnings
# warnings.filterwarnings("ignore")
# import numpy as np
# import pandas as pd
# import pickle
# from sklearn import preprocessing
# from sklearn import model_selection
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.metrics import roc_auc_score,r2_score,mean_absolute_error,mean_squared_error,accuracy_score,classification_report,confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DataCoSupplyChainDataset.csv',header= 0,encoding='unicode_escape')
pd.set_option('display.max_columns',None)
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
df.loc[180500]
# Out:
# Type                                                                 DEBIT
# Days for shipping (real)                                                 3
# Days for shipment (scheduled)                                            4
# Benefit per order                                               138.229996
# Sales per customer                                              383.980011
# Delivery Status                                           Advance shipping
# Late_delivery_risk                                                       0
# Category Id                                                             45
# Category Name                                                      Fishing
# Customer City                                                   Saint Paul
# Customer Country                                                   EE. UU.
# Customer Id                                                            773
# ...

# %%
# Dropping the specified columns: 'Customer Password', 'Customer Email', etc.
columns_to_drop = ['Customer Password', 'Customer Email', 'Customer Fname', 'Customer Lname', 'Product Description', 'Product Image']
# Dropping the columns from the dataset
data_cleaned = df.drop(columns=columns_to_drop)
data_cleaned.to_csv('data_cleaned.csv', index=False, encoding='utf-8')

# %%
data_cleaned.to_csv('data_cleaned.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('data_cleaned.csv')
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
sub_shipping = df[['Days for shipping (real)', 'Days for shipment (scheduled)', 'Late_delivery_risk', 'Order Status']]
sub_shipping['Days for shipping (real)'] = pd.to_numeric(sub_shipping['Days for shipping (real)'])
sub_shipping['Days for shipment (scheduled)'] = pd.to_numeric(sub_shipping['Days for shipment (scheduled)'])
sub_shipping['different'] = sub_shipping['Days for shipping (real)'] - sub_shipping['Days for shipment (scheduled)']
sub_shipping['different'] = sub_shipping['different'].apply(lambda x : 1 if x > 0 else 0)
sub_shipping['Compare'] = sub_shipping['different'] == sub_shipping['Late_delivery_risk']
sub_shipping['Compare'].value_counts()
# 'Compare' 열에서 True가 아닌 행을 필터링
filtered_df = sub_shipping[sub_shipping['Compare'] != True]
# 필터링된 결과 출력
print(filtered_df)

# %%
sales = df[['Sales', 'Order Item Total', 'Order Profit Per Order']]
sales
# Out:
#              Sales  Order Item Total  Order Profit Per Order
# 0       327.750000        314.640015               91.250000
# 1       327.750000        311.359985             -249.089996
# 2       327.750000        309.720001             -247.779999
# 3       327.750000        304.809998               22.860001
# 4       327.750000        298.250000              134.210007
# ...            ...               ...                     ...
# 180514  399.980011        399.980011               40.000000
# 180515  399.980011        395.980011             -613.770019
# 180516  399.980011        391.980011              141.110001
# 180517  399.980011        387.980011              186.229996
# 180518  399.980011        383.980011              168.949997
#
# [180519 rows x 3 columns]

# %%
plt.figure(figsize=(10, 10))
ax = sns.heatmap(sales.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numeric Features', fontsize=20)
plt.show()

# %%
minus_benefit = df[df['Benefit per order'] < 0] 
minus_benefit.count()
# Out:
# Type                             33784
# Days for shipping (real)         33784
# Days for shipment (scheduled)    33784
# Benefit per order                33784
# Sales per customer               33784
# Delivery Status                  33784
# Late_delivery_risk               33784
# Category Id                      33784
# Category Name                    33784
# Customer City                    33784
# Customer Country                 33784
# Customer Email                   33784
# Customer Fname                   33784
# Customer Id                      33784
# Customer Lname                   33782
# Customer Password                33784
# Customer Segment                 33784
# Customer State                   33784
# Customer Street                  33784
# Customer Zipcode                 33784
# Department Id                    33784
# Department Name                  33784
# Latitude                         33784
# Longitude                        33784
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(25, 25))
ax = sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numeric Features', fontsize=20)
plt.show()

# %%
category_sales_profit = df.groupby('Category Name').agg({
    'Sales per customer': 'sum',
    'Benefit per order': 'sum'
}).reset_index()

# %%
counts = df['Category Name'].value_counts()

# %%
profit = pd.merge(counts, category_sales_profit, on='Category Name', how='inner')

# %%
profit
# Out:
#            Category Name  count  Sales per customer  Benefit per order
# 0                 Cleats  24551        3.982857e+06      494636.919791
# 1         Men's Footwear  22246        2.598494e+06      311902.820214
# 2        Women's Apparel  21035        2.828708e+06      350421.029567
# 3   Indoor/Outdoor Games  19298        2.596454e+06      318451.430554
# 4                Fishing  17325        6.226935e+06      756220.767190
# 5           Water Sports  15540        2.798044e+06      325146.960038
# 6       Camping & Hiking  13729        3.700784e+06      427455.568106
# 7       Cardio Equipment  12487        3.320251e+06      383011.098485
# 8          Shop By Sport  10984        1.177186e+06      129813.960315
# 9            Electronics   3156        3.333273e+05       40891.379918
# 10           Accessories   1780        1.197125e+05       16643.520074
# 11            Golf Balls   1475        6.934125e+04        8342.670024
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Category Name', y='Sales per customer', data=profit, color='blue', label='Sales')
sns.barplot(x='Category Name', y='Benefit per order', data=profit, color='green', label='Profit', alpha=0.7)
plt.title('Category-wise Sales and Profit Contribution')
plt.xlabel('Category Name')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
order_status_sales = df.groupby('Order Status').agg({
    'Sales per customer': 'sum'
}).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Order Status', y='Sales per customer', data=order_status_sales, palette='coolwarm')
plt.title('Sales by Order Status')
plt.xlabel('Order Status')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Order Item Discount Rate', y='Order Item Profit Ratio', data=df)
plt.title('Profit Ratio vs Discount Rate')
plt.xlabel('Discount Rate')
plt.ylabel('Profit Ratio')
plt.show()

# %%
df.head(3)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# 1                   1           73  Sporting Goods        Caguas  ...
# 2                   0           73  Sporting Goods      San Jose  ...
#
#        Order State  Order Status Order Zipcode Product Card Id  \
# 0  Java Occidental      COMPLETE           NaN            1360
# ...

# %%
result = df[['Order Id', 'Category Id']].value_counts().reset_index(name='count')
count = df.groupby(['Order Id', 'Product Card Id']).size().reset_index(name='Count')

# %%
result = result.sort_values(by=['count', 'Order Id'], ascending=False)

# %%
count = count.sort_values(by=['Count', 'Order Id'], ascending=False)

# %%
result[result['count'] > 2].count()
# Out:
# Order Id       1659
# Category Id    1659
# count          1659
# dtype: int64

# %%
count[count['Count'] > 2].count()
# Out:
# Order Id           1644
# Product Card Id    1644
# Count              1644
# dtype: int64

# %%
# Group by product name to get total sales and quantity sold per product
product_sales_analysis = df.groupby(['Product Name', 'Category Name']).agg(
    total_sales=('Sales', 'sum'),
    total_quantity_sold=('Order Item Quantity', 'sum')
).reset_index()

# Sort products by total quantity sold to get top 5 and bottom 5
top_5_products = product_sales_analysis.sort_values(by='total_quantity_sold', ascending=False).head(5)
bottom_5_products = product_sales_analysis.sort_values(by='total_quantity_sold', ascending=True).head(5)

top_5_products, bottom_5_products
# Out:
# (                                      Product Name         Category Name  \
#  71                Perfect Fitness Perfect Rip Deck                Cleats
#  59            Nike Men's Dri-FIT Victory Golf Polo       Women's Apparel
#  67                O'Brien Men's Neoprene Life Vest  Indoor/Outdoor Games
#  61               Nike Men's Free 5.0+ Running Shoe      Cardio Equipment
#  102  Under Armour Girls' Toddler Spine Surge Runni         Shop By Sport
#
#        total_sales  total_quantity_sold
#  71   4.421143e+06                73698
#  59   3.147800e+06                62956
#  67   2.888994e+06                57803
#  61   3.667633e+06                36680
#  102  1.269083e+06                31735  ,
#                                       Product Name        Category Name  \
#  4               Bowflex SelectTech 1090 Dumbbells  Fitness Accessories
#  76                            SOLE E25 Elliptical           Basketball
# ...

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Plot for top 5 products
plt.subplot(1, 2, 1)
sns.barplot(x='total_quantity_sold', y='Product Name', data=top_5_products, palette="Blues_d")
plt.title('Top 5 Products by Sales Quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')

# Plot for bottom 5 products
plt.subplot(1, 2, 2)
sns.barplot(x='total_quantity_sold', y='Product Name', data=bottom_5_products, palette="Reds_d")
plt.title('Bottom 5 Products by Sales Quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by product name to get total sales and quantity sold per product
category_sales_analysis = df.groupby(['Category Name']).agg(
    total_sales=('Sales', 'sum'),
    total_quantity_sold=('Order Item Quantity', 'sum'),
    total_profit=('Order Profit Per Order', 'sum')
).reset_index()

# Sort products by total quantity sold to get top 5 and bottom 5
top_5_categories = category_sales_analysis.sort_values(by='total_quantity_sold', ascending=False).head(5)
bottom_5_categories = category_sales_analysis.sort_values(by='total_quantity_sold', ascending=True).head(5)

top_5_categories, bottom_5_categories
# Out:
# (           Category Name   total_sales  total_quantity_sold   total_profit
#  12                Cleats  4.431943e+06                73734  494636.919791
#  47       Women's Apparel  3.147800e+06                62956  350421.029567
#  30  Indoor/Outdoor Games  2.888994e+06                57803  318451.430554
#  10      Cardio Equipment  3.694843e+06                37587  383011.098485
#  38         Shop By Sport  1.309522e+06                32726  129813.960315,
#          Category Name   total_sales  total_quantity_sold  total_profit
#  23  Golf Bags & Carts  10369.390336                   61   1810.069992
#  4          Basketball  27099.329343                   67   1845.670003
#  41  Strength Training  54895.529536                  111    332.310091
#  1     As Seen on  TV!  20597.939964                  206    714.429980
#  2               Baby   12229.560379                  207   1525.029992)

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Plot for top 5 products
plt.subplot(1, 2, 1)
sns.barplot(x='total_quantity_sold', y='Category Name', data=top_5_categories, palette="Blues_d")
plt.title('Top 5 Products by Sales Quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')

# Plot for bottom 5 products
plt.subplot(1, 2, 2)
sns.barplot(x='total_quantity_sold', y='Category Name', data=bottom_5_categories, palette="Reds_d")
plt.title('Bottom 5 Products by Sales Quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Grouping data by Product Name to get discount-related metrics
discount_analysis = df.groupby('Product Name').agg(
    total_discount=('Order Item Discount', 'sum'),
    total_sales=('Sales', 'sum'),
    total_quantity_sold=('Order Item Quantity', 'sum'),
    total_profit=('Order Profit Per Order', 'sum')
).reset_index()

# Plotting the relationship between discount and sales, and discount and profit
plt.figure(figsize=(14, 6))

# Subplot 1: Discount vs Sales
plt.subplot(1, 2, 1)
sns.scatterplot(x='total_discount', y='total_sales', data=discount_analysis, hue='total_quantity_sold', palette='cool', size='total_quantity_sold', sizes=(20, 200))
plt.title('Discount vs Sales')
plt.xlabel('Total Discount')
plt.ylabel('Total Sales')

# Subplot 2: Discount vs Profit
plt.subplot(1, 2, 2)
sns.scatterplot(x='total_discount', y='total_profit', data=discount_analysis, hue='total_quantity_sold', palette='viridis', size='total_quantity_sold', sizes=(20, 200))
plt.title('Discount vs Profit')
plt.xlabel('Total Discount')
plt.ylabel('Total Profit')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
discount_analysis.sort_values(by='total_profit', ascending=True).head(10)
# Out:
#                                      Product Name  total_discount  \
# 77                            SOLE E35 Elliptical     3590.000000
# 9          Bushnell Pro X7 Jolt Slope Rangefinder      537.000000
# 76                            SOLE E25 Elliptical      585.000000
# 36              GoPro HERO3+ Black Edition Camera     1198.000000
# 20  Diamondback Girls' Clarity 24 Hybrid Bike 201      775.500000
# 73                    Polar Loop Activity Tracker      602.010001
# 13  Cleveland Golf Women's 588 RTX CB Satin Chrom      861.000003
# 10                                    CDs of rock      309.559999
# 30              Garmin Forerunner 910XT GPS Watch     1406.000000
# 80  Stiga Master Series ST3100 Competition Indoor      755.699999
#
#      total_sales  total_quantity_sold  total_profit
# 77  29999.849850                   15   -965.119968
# 9    6599.889892                   11   -255.950003
# 76   9999.899902                   10   -169.559997
# ...
